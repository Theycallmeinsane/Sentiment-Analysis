# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn

# %%
import nltk

# %%
nltk.download('sentiwordnet')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\hadii\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hadii\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# a synset is a set of synonymous words that represent a specific concept or meaning.

# %%
wn.synsets('bank')
# Out:
# [Synset('bank.n.01'),
#  Synset('depository_financial_institution.n.01'),
#  Synset('bank.n.03'),
#  Synset('bank.n.04'),
#  Synset('bank.n.05'),
#  Synset('bank.n.06'),
#  Synset('bank.n.07'),
#  Synset('savings_bank.n.02'),
#  Synset('bank.n.09'),
#  Synset('bank.n.10'),
#  Synset('bank.v.01'),
#  Synset('bank.v.02'),
#  Synset('bank.v.03'),
#  Synset('bank.v.04'),
#  Synset('bank.v.05'),
#  Synset('deposit.v.02'),
#  Synset('bank.v.07'),
#  Synset('trust.v.01')]

# %% [markdown]
# with definitions

# %%
word_list = list(wn.synsets('bank'))
for wl in word_list:
    print(wl, wl.definition())
# Out:
# Synset('bank.n.01') sloping land (especially the slope beside a body of water)
# Synset('depository_financial_institution.n.01') a financial institution that accepts deposits and channels the money into lending activities
# Synset('bank.n.03') a long ridge or pile
# Synset('bank.n.04') an arrangement of similar objects in a row or in tiers
# Synset('bank.n.05') a supply or stock held in reserve for future use (especially in emergencies)
# Synset('bank.n.06') the funds held by a gambling house or the dealer in some gambling games
# Synset('bank.n.07') a slope in the turn of a road or track; the outside is higher than the inside in order to reduce the effects of centrifugal force
# Synset('savings_bank.n.02') a container (usually with a slot in the top) for keeping money at home
# Synset('bank.n.09') a building in which the business of banking transacted
# Synset('bank.n.10') a flight maneuver; aircraft tips laterally about its longitudinal axis (especially in turning)
# ...

# %% [markdown]
# with definitions and examples (wherever available)

# %%
word_list = list(wn.synsets('bank'))
for wl in word_list:
    print(wl, wl.definition())
    if (len(wl.examples()) > 0):
        print("---------------------", wl.examples()[0])
# Out:
# Synset('bank.n.01') sloping land (especially the slope beside a body of water)
# --------------------- they pulled the canoe up on the bank
# Synset('depository_financial_institution.n.01') a financial institution that accepts deposits and channels the money into lending activities
# --------------------- he cashed a check at the bank
# Synset('bank.n.03') a long ridge or pile
# --------------------- a huge bank of earth
# Synset('bank.n.04') an arrangement of similar objects in a row or in tiers
# --------------------- he operated a bank of switches
# Synset('bank.n.05') a supply or stock held in reserve for future use (especially in emergencies)
# Synset('bank.n.06') the funds held by a gambling house or the dealer in some gambling games
# --------------------- he tried to break the bank at Monte Carlo
# Synset('bank.n.07') a slope in the turn of a road or track; the outside is higher than the inside in order to reduce the effects of centrifugal force
# ...

# %%
import nltk
nltk.download('omw')
# Out:
# [nltk_data] Downloading package omw to
# [nltk_data]     C:\Users\hadii\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# True

# %%
sorted(wn.langs())
# Out:
# ['eng']

# %% [markdown]
# again with definitions and examples

# %%
word_list = list(wn.synsets('Apple'))
for wl in word_list:
    print(wl, wl.definition())    
    if (len(wl.examples()) > 0):
        print("---------------------", wl.examples()[0])
# Out:
# Synset('apple.n.01') fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
# Synset('apple.n.02') native Eurasian tree widely cultivated in many varieties for its firm rounded edible fruits

# %%
dog = wn.synset('dog.n.01')
dog.hypernyms()
# Out:
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]

# %%
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
dog = wn.synsets('tiger')[0]
cat = wn.synsets('lion')[0] #experiment
dog.path_similarity(cat)
cat=wn.synsets('cat')[0]
kitten=wn.synsets('kitten')[0]
cat.path_similarity(kitten)
# Out:
# 0.09090909090909091

# %% [markdown]
# The process of assigning sentiment scores to synsets is time-consuming and requires significant expertise in both natural language processing and sentiment analysis. In the case of SentimentWordNet, the scores were assigned by a team of researchers led by Finn Årup Nielsen at the Technical University of Denmark. The researchers used a combination of crowdsourcing and expert annotation to develop the scores, and they have since been validated through a number of experiments and evaluations.

# %%
word_list = list(wn.synsets('pathetic'))
for wl in word_list:
    print(wl, wl.definition())
    if (len(wl.examples()) > 0):
        print("---------------------", wl.examples()[0])  

answer = list(swn.senti_synsets('pathetic'))
for a in answer:    
    print(a.pos_score()) 
    print(a.neg_score())
    print(a)
# Out:
# Synset('hapless.s.01') deserving or inciting pity; ; ; - Galsworthy
# --------------------- a hapless victim
# Synset('pathetic.s.02') inspiring mixed contempt and pity
# --------------------- their efforts were pathetic
# Synset('pathetic.s.03') inspiring scornful pity; - Dashiell Hammett
# --------------------- how silly an ardent and unsuccessful wooer can be especially if he is getting on in years
# 0.125
# 0.875
# <hapless.s.01: PosScore=0.125 NegScore=0.875>
# 0.333
# 0.667
# <pathetic.s.02: PosScore=0.333 NegScore=0.667>
# 0.0
# 0.625
# <pathetic.s.03: PosScore=0.0 NegScore=0.625>

# %%
answer = list(swn.senti_synsets('wastage'))[0]
print(answer.pos_score()) 
print(answer.neg_score())
print(answer)
if (answer.pos_score() > answer.neg_score()):
    print("positive word")
elif (answer.pos_score() > 0):
    print("negative word")
else: 
    print("neutral word")
# Out:
# 0.0
# 0.0
# <wastage.n.01: PosScore=0.0 NegScore=0.0>
# neutral word

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
import nltk
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
#nltk.download('sentiwordnet')

# %%
import os
print(os.getcwd())
#change working directory to the location of the data file
os.chdir('D:/Semesters/Spring 24/Introduction to Text Analytics/Assignment-2/')
print(os.getcwd())
# Out:
# d:\Semesters\Spring 24\Introduction to Text Analytics\Assignment-2
# D:\Semesters\Spring 24\Introduction to Text Analytics\Assignment-2

# %%
import pandas as pd

# %%
# load the dataset
df=pd.read_csv('train.csv')

# %% [markdown]
# ### Senti WordNet

# %%
awesome = list(swn.senti_synsets('awesome', 'a'))[0]
print('Positive Polarity Score:', awesome.pos_score())
print('Negative Polarity Score:', awesome.neg_score())
print('Objective Score:', awesome.obj_score())
# Out:
# Positive Polarity Score: 0.875
# Negative Polarity Score: 0.125
# Objective Score: 0.0

# %%
y_pred = []
for t in X_test:
    pos_score = 0
    neg_score = 0
    for word in t.split():
        syn = list(swn.senti_synsets(word))
        if (len(syn) > 0):
            pos_score = pos_score + syn[0].pos_score()
            neg_score = neg_score + syn[0].neg_score()
    if (pos_score > neg_score):
        y_pred.append('positive')
    else:
        y_pred.append('negative')

print(accuracy_score(df['sentiment'], y_pred))
# Out:
# 0.6077333333333333

# %% [markdown]
# ### Afinn Score

# %%
from afinn import Afinn
afn = Afinn(emoticons=True)

# %%
df['review'][0]
# Out:
# "SAPS AT SEA <br /><br />Aspect ratio: 1.37:1<br /><br />Sound format: Mono<br /><br />(Black and white)<br /><br />Suffering from 'hornophobia', Ollie embarks on a 'restful' boat trip, but he and Stan get mixed up with an escaped convict (Rychard Cramer). Chaos ensues.<br /><br />This feature length comedy - an OK entry which nonetheless unspools like a mere imitation of Laurel and Hardy's best work - marked the final collaboration between L&H and producer Hal Roach. Episodic in structure, the movie culminates in a memorable ocean voyage after The Boys are taken hostage by villainous Cramer (who shoots a seagull to prove how tough he is!). The gags are OK, but inspiration is lacking, perhaps due to the recruitment of actor-turned-director Gordon Douglas, previously responsible for Ollie's first solo effort in the sound era (ZENOBIA, produced in 1939), but whose work here lacks a measure of pzazz. Fair, but nothing special. L&H regulars Charlie Hall and James Finlayson make guest app
# ...

# %%
afn.score(df['review'][0])
# Out:
# 13.0

# %%
df['review'][6]
# Out:
# 'Before I continue forth with the new millennium, I will go back in time once more because I had completely forgotten about these gems!!!!!<br /><br />In 1987, Disney, while still a "low" company in the 80s, was able to start a series of films on television called "Not Quite Human," about a geeky teenager who, like in "Inspector Gadget," looks like a human but is really a robot!!!!! Now this SCREAMS 80S, along with other films like "Tron" and "Honey, I Shrunk The Kids" because it combines everything of yesteryear with the technologies of tomorrow!!!!!<br /><br />My parents remember seeing this on the TV back then, back when I was just born or something. However, my very first encounter with this film was on the Old Disney Channel (one time, I\'ve seen this, and the other parts, on my 12th B\'day in May of \'99!!!!!)<br /><br />"Not Quite Human" is a very good series of films to watch, if you can ever find these movies again. <br /><br />Has this been shown recently? If so, give me an
# ...

# %%
afn.score(df['review'][6])
# Out:
# 6.0

# %%
sentiment_polarity = [afn.score(review) for review in df['review']]
y_pred = ['positive' if score >= 1.0 else 'negative' for score in sentiment_polarity]
print(sentiment_polarity[11:16])
print(y_pred[11:16])
# Out:
# [9.0, -3.0, 8.0, -28.0, 2.0]
# ['positive', 'negative', 'positive', 'negative', 'positive']

# %%
accuracy_score(df['sentiment'], y_pred)
# Out:
# 0.7065333333333333

# %% [markdown]
# #### only using Nouns, Verbs, Adjectives and Adverbs

# %%
import spacy
nlp = spacy.load('en_core_web_md')

# %%
y_pred = []
for t in df['review']:
    tagged_text = [(token.text, token.tag_) for token in nlp(t)]
    pos_score = neg_score = token_count = obj_score = 0
    for word, tag in tagged_text:        
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        if ss_set:
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    y_pred.append(final_sentiment)
accuracy_score(df['sentiment'], y_pred)
# Out:
# 0.5958666666666667

# %% [markdown]
# ### Sentiment Intensity Analyzer

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')

# %% [markdown]
# The compound score is the sum of positive, negative & neutral scores which is then normalized between -1(most extreme negative) and +1 (most extreme positive).<br>
# The more Compound score closer to +1, the higher the positivity of the text.

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hadii\AppData\Roaming\nltk_data...
# True

# %%
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(df['review'][6])
scores
# Out:
# {'neg': 0.041, 'neu': 0.893, 'pos': 0.066, 'compound': 0.6762}

# %% [markdown]
# https://blog.quantinsti.com/vader-sentiment/

# %%
scores['compound']
# Out:
# 0.6762

# %%
agg_score = scores['compound']
final_sentiment = 'positive' if agg_score >= 0.1 else 'negative'

sentiment_polarity = [analyzer.polarity_scores(review)['compound'] for review in df['review']]
y_pred = ['positive' if score >= 0.1 else 'negative' for score in sentiment_polarity]
accuracy_score(df['sentiment'], y_pred)
# Out:
# 0.6949333333333333

# %%
import pandas as pd
import os
import numpy as np
df=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')

# %%
y_pred = []
for t in df['review']:
    pos_score = 0
    neg_score = 0
    for word in t.split():
        syn = list(swn.senti_synsets(word))
        if (len(syn) > 0):
            pos_score = pos_score + syn[0].pos_score()
            neg_score = neg_score + syn[0].neg_score()
    if (pos_score > neg_score):
        y_pred.append('positive')
    else:
        y_pred.append('negative')

print("Simple:",accuracy_score(df['sentiment'], y_pred))
from afinn import Afinn
afn = Afinn(emoticons=True)
sentiment_polarity = [afn.score(review) for review in df['review']]
y_pred = ['positive' if score >= 1.0 else 'negative' for score in sentiment_polarity]
print(sentiment_polarity[0:len(sentiment_polarity)])
print(y_pred[0:len(y_pred)])
accuracy_score(df['sentiment'], y_pred)
import spacy
nlp = spacy.load('en_core_web_md')
y_pred = []
for t in df['review']:
    tagged_text = [(token.text, token.tag_) for token in nlp(t)]
    pos_score = neg_score = token_count = obj_score = 0
    for word, tag in tagged_text:        
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        if ss_set:
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    y_pred.append(final_sentiment)
print("Noun,Verb:",accuracy_score(df['sentiment'], y_pred))

from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(df['review'][6])
scores
agg_score = scores['compound']
final_sentiment = 'positive' if agg_score >= 0.1 else 'negative'

sentiment_polarity = [analyzer.polarity_scores(review)['compound'] for review in df['review']]
y_pred = ['positive' if score >= 0.1 else 'negative' for score in sentiment_polarity]
print("Vader Lexicon:",accuracy_score(df['sentiment'], y_pred))
# Out:
# Simple: 0.6097
# ...

# %% [markdown]
# Stop Words and Stemmed Dataset

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

df_test_stemmed=pd.read_csv('test.csv')
df_test_stemmed['review'] = df_test_stemmed['review'].str.lower()
stop = stopwords.words('english')
df_test_stemmed['review'] = df_test_stemmed['review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
stemmer = PorterStemmer()
df_test_stemmed['review'] = df_test_stemmed['review'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split()]))
vectorizer = CountVectorizer(tokenizer=word_tokenize, token_pattern=None)

y_pred = []
for t in df_test_stemmed['review']:
    pos_score = 0
    neg_score = 0
    for word in t.split():
        syn = list(swn.senti_synsets(word))
        if (len(syn) > 0):
            pos_score = pos_score + syn[0].pos_score()
            neg_score = neg_score + syn[0].neg_score()
    if (pos_score > neg_score):
        y_pred.append('positive')
    else:
        y_pred.append('negative')

print("Simple:",accuracy_score(df_test_stemmed['sentiment'], y_pred))
from afinn import Afinn
afn = Afinn(emoticons=True)
sentiment_polarity = [afn.score(review) for review in df_test_stemmed['review']]
y_pred = ['positive' if score >= 1.0 else 'negative' for score in sentiment_polarity]
print(sentiment_polarity[0:len(sentiment_polarity)])
print(y_pred[0:len(y_pred)])
accuracy_score(df_test_stemmed['sentiment'], y_pred)
import spacy
nlp = spacy.load('en_core_web_md')
y_pred = []
for t in df_test_stemmed['review']:
    tagged_text = [(token.text, token.tag_) for token in nlp(t)]
    pos_score = neg_score = token_count = obj_score = 0
    for word, tag in tagged_text:        
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        if ss_set:
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    y_pred.append(final_sentiment)
print("Noun,Verb:",accuracy_score(df_test_stemmed['sentiment'], y_pred))

from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(df_test_stemmed['review'][6])
scores
agg_score = scores['compound']
final_sentiment = 'positive' if agg_score >= 0.1 else 'negative'

sentiment_polarity = [analyzer.polarity_scores(review)['compound'] for review in df_test_stemmed['review']]
y_pred = ['positive' if score >= 0.1 else 'negative' for score in sentiment_polarity]
print("Vader Lexicon:",accuracy_score(df_test_stemmed['sentiment'], y_pred))
# Out:
# Simple: 0.618
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
df_test_stemmed=pd.read_csv('test.csv')
df_test_stemmed['review'] = df_test_stemmed['review'].str.lower()
stop = stopwords.words('english')
df_test_stemmed['review'] = df_test_stemmed['review'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
lemmatizer=WordNetLemmatizer()
df_test_stemmed['review'] = df_test_stemmed['review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
vectorizer = CountVectorizer(tokenizer=word_tokenize, token_pattern=None)

y_pred = []
for t in df_test_stemmed['review']:
    pos_score = 0
    neg_score = 0
    for word in t.split():
        syn = list(swn.senti_synsets(word))
        if (len(syn) > 0):
            pos_score = pos_score + syn[0].pos_score()
            neg_score = neg_score + syn[0].neg_score()
    if (pos_score > neg_score):
        y_pred.append('positive')
    else:
        y_pred.append('negative')

print("Simple:",accuracy_score(df_test_stemmed['sentiment'], y_pred))
from afinn import Afinn
afn = Afinn(emoticons=True)
sentiment_polarity = [afn.score(review) for review in df_test_stemmed['review']]
y_pred = ['positive' if score >= 1.0 else 'negative' for score in sentiment_polarity]
print(sentiment_polarity[0:len(sentiment_polarity)])
print(y_pred[0:len(y_pred)])
accuracy_score(df_test_stemmed['sentiment'], y_pred)
import spacy
nlp = spacy.load('en_core_web_md')
y_pred = []
for t in df_test_stemmed['review']:
    tagged_text = [(token.text, token.tag_) for token in nlp(t)]
    pos_score = neg_score = token_count = obj_score = 0
    for word, tag in tagged_text:        
        ss_set = None
        if 'NN' in tag and list(swn.senti_synsets(word, 'n')):
            ss_set = list(swn.senti_synsets(word, 'n'))[0]
        elif 'VB' in tag and list(swn.senti_synsets(word, 'v')):
            ss_set = list(swn.senti_synsets(word, 'v'))[0]
        elif 'JJ' in tag and list(swn.senti_synsets(word, 'a')):
            ss_set = list(swn.senti_synsets(word, 'a'))[0]
        elif 'RB' in tag and list(swn.senti_synsets(word, 'r')):
            ss_set = list(swn.senti_synsets(word, 'r'))[0]
        if ss_set:
            pos_score += ss_set.pos_score()
            neg_score += ss_set.neg_score()
            obj_score += ss_set.obj_score()
            token_count += 1
    final_score = pos_score - neg_score
    norm_final_score = round(float(final_score) / token_count, 2)
    final_sentiment = 'positive' if norm_final_score >= 0 else 'negative'
    y_pred.append(final_sentiment)
print("Noun,Verb:",accuracy_score(df_test_stemmed['sentiment'], y_pred))

from nltk.sentiment.vader import SentimentIntensityAnalyzer
#nltk.download('vader_lexicon')
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(df_test_stemmed['review'][6])
scores
agg_score = scores['compound']
final_sentiment = 'positive' if agg_score >= 0.1 else 'negative'

sentiment_polarity = [analyzer.polarity_scores(review)['compound'] for review in df_test_stemmed['review']]
y_pred = ['positive' if score >= 0.1 else 'negative' for score in sentiment_polarity]
print("Vader Lexicon:",accuracy_score(df_test_stemmed['sentiment'], y_pred))
# Out:
# Simple: 0.6246
# ...
